# %%
from IPython.display import Image

# %% [markdown]
# # Machine Learning. An introduction.

# %% [markdown]
# *Machine learning is a field of computer science that uses statistical techniques to give computer systems the ability to "learn"* [1]
#
# [1]: https://en.wikipedia.org/wiki/Machine_learning

# %% [markdown]
# ## Types of machine learning

# %% [markdown]
# ![01_01.png](attachment:01_01.png)

# %% [markdown]
# [1]: https://en.wikipedia.org/wiki/Machine_learning

# %% [markdown]
# ## Supervised learning from data
# ![01_02.png](attachment:01_02.png)

# %% [markdown]
# ### Building machine learning systems for prediction
# ![01_09.png](attachment:01_09.png)

# %% [markdown]
# ## Supervised learning from data: Regression

# %%
Image(filename='images/01_04.png', width=500)

# %% [markdown]
# ## Supervised learning from data: Classification

# %%
Image(filename='images/01_03.png', width=500)

# %% [markdown]
# ## Unsupervised learning from data: Classification

# %%
Image(filename='images/01_06.png', width=500)

# %% [markdown]
# ## Unsupervised learning from data: Dimensionality reduction

# %%
Image(filename='images/01_07.png', width=700)

# %% [markdown]
# ## Linear vs nonlinear

# %%
Image(filename='images/01_x.png', width=500)

# %% [markdown]
# Images are from [www.kdnuggets.com](https://www.kdnuggets.com/2018/09/6-steps-write-machine-learning-algorithm.html)

# %% [markdown]
# ## Learning strategy/policy with reinforcement learning

# %%
Image(filename='images/01_05.png', width=500)

# %% [markdown]
# ## Books!
#
# 1.  *A first course in machine learning* Simon Rogers, Mark Girolami. Rogers Simon, Girolami Mark
#
# 2. *Uczenie maszynowe dla programistów* Drew Conway, John Myles White (słabe i z R)
#
# 3. *Python machine learning: unlock deeper insights into machine learning with this vital guide to cutting-edge predictive analytics* Sebastian Raschka (*Python: uczenie maszynowe* Sebastian Raschka)
#
# 4. *Foundations of machine learning* Mehryar Mohri, Ashin Rostamizadeh, and Ameet Talwalkar. (for math masochists)
#
# 5. *Introduction to machine learning with Python: a guide for data scientists* Andreas C. Müller and Sarah Guid
#
# 6. *Python w uczeniu maszynowym: podejście sterowane testami* Matthew Kirk
#
# 7. *Uczenie maszynowe z użyciem Scikit-Learn i TensorFlow: pojęcia, techniki i narzędzia służące do tworzenia inteligentnych systemów* Aurélien Géron

# %% [markdown]
# # References
# __ALL images (unless otherwise stated) are from book__: Raschka, Sebastian. Python machine learning. Birmingham, UK: Packt Publishing, 2015, ISBN 1783555130
#
# [1] https://en.wikipedia.org/wiki/Machine_learning
# [2] https://www.kdnuggets.com/2018/09/6-steps-write-machine-learning-algorithm.html
